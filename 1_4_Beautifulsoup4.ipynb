# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())
# <html>
# <head>
# <title>
# The Dormouse's story
# </title>
# </head>
# <body>
# <p class="title">
# <b>
# The Dormouse's story
# </b>
# </p>
# <p class="story">
# Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">
# Elsie
# </a>
# ,
# <a class="sister" href="http://example.com/lacie" id="link2">
# Lacie
# </a>
# and
# <a class="sister" href="http://example.com/tillie" id="link3">
# Tillie
# </a>
# ; and they lived at the bottom of a well.
# </p>
# <p class="story">
# ...
# </p>
# </body>
# </html>
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# Podemos navegar por la estructura de datos:

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# Una operación habitual es extraer las URLs encontradas en las páginas con la etiqueta <a>:

# %%
for link in soup.find_all('a'):
 print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# Otra tarea habitual es extraer todo el texto de una página:

# %%
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
conda install -c anaconda requests
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     requests-2.27.1            |     pyhd3eb1b0_0          52 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:          52 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   requests                                        pkgs/main --> anaconda
#
#
#
# ...
#
# requests-2.27.1      | 52 KB     |            |   0%
# requests-2.27.1      | 52 KB     | ###        |  31%
# requests-2.27.1      | 52 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ...

# %%
url1=input ("Introduzca url a investigar:")
print(url1)
# Out:
# Introduzca url a investigar:https://adaptive-training.com/
# https://adaptive-training.com/

# %%
import requests
resp = requests.get(url1)

# %%
#debe tener instalada la librería html5lib
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import html5lib
soup=BeautifulSoup(resp.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <title>Formación Adaptativa – Transformación Digital</title>
# <link href="//static.addtoany.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://adaptive-training.com/feed/" rel="alternate" title="Formación Adaptativa » Feed" type="application/rss+xml"/>
# <link href="https://adaptive-training.com/comments/feed/" rel="alternate" title="Formación Adaptativa » Feed de los comentarios" type="application/rss+xml"/>
# <link href="https://adaptive-training.com/inicio/feed/" rel="alternate" title="Formación Adaptativa » Comentario Inicio del feed" type="application/rss+xml"/>
# ...

# %%
primer_parrafo = soup.p
texto = primer_parrafo.string
print(texto)
type(texto)
# Out:
# EL PORQUÉ DE LAS FUNDACIONES CORPORATIVAS   La razón de ser de las fundaciones en el ámbito corporativo hay que buscarlo en el marco de la Responsabilidad Social Corporativa, pues se emplean como instrumentos de la misma persiguiendo lograr sus cuatro objetivos: (1) contribuir a la sociedad de forma éticamente correcta, (2) unir las expectativas…
# bs4.element.NavigableString

# %%
soup.meta['charset']
# Out:
# 'UTF-8'

# %%
#veamos los hijos de primer nivel:
soup.contents
# Out:
# ['html',
#  '\n',
#  <html lang="es">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <link href="https://gmpg.org/xfn/11" rel="profile"/>
#  <title>Formación Adaptativa – Transformación Digital</title>
#  <link href="//static.addtoany.com" rel="dns-prefetch"/>
#  <link href="//s.w.org" rel="dns-prefetch"/>
#  <link href="https://adaptive-training.com/feed/" rel="alternate" title="Formación Adaptativa » Feed" type="application/rss+xml"/>
#  <link href="https://adaptive-training.com/comments/feed/" rel="alternate" title="Formación Adaptativa » Feed de los comentarios" type="application/rss+xml"/>
#  <link href="https://adaptive-training.com/inicio/feed/" rel="alternate" title="Formación Adaptativa » Comentario Inicio del feed" type="application/rss+xml"/>
# ...

# %%
#Extracción de contenidos por etiquetas
enlaces = soup.find_all('a')
for enlace in enlaces:
    print(enlace)
# Out:
# <a aria-label="Skip to content" class="fl-screen-reader-text" href="#fl-main-content">Skip to content</a>
# <a href="https://adaptive-training.com/"><div class="fl-logo-text" itemprop="name">Minería de Datos Educativos, Análisis de Inteligencia</div></a>
# <a aria-current="page" class="nav-link" href="https://adaptive-training.com/">Inicio</a>
# <a class="nav-link" href="https://adaptive-training.com/objetivo/">Objetivo</a>
# <a class="nav-link" href="https://adaptive-training.com/biblioteca/">Biblioteca</a>
# <a class="nav-link" href="https://adaptive-training.com/herrramientas-mineria-datos/">Herramientas</a>
# <a class="nav-link" href="https://adaptive-training.com/sobre-mi/">Sobre mí</a>
# <a href="https://adaptive-training.com/" itemprop="url"><div class="fl-logo-text" itemprop="name">Minería de Datos Educativos, Análisis de Inteligencia</div></a>
# <a aria-expanded="false" aria-haspopup="true" aria-label="Search" class="fas fa-search" href="#" id="flsearchform"></a>
# ...

# %% [markdown]
# EXTRAEMOS TODAS LAS URL QUE APARECEN EN LA PÁGINA WEB:

# %%
#Extraemos todas las url que aparecen en la página web
import requests
from bs4 import BeautifulSoup
 
url1=input ("Introduzca url a investigar:") 

reqs = requests.get(url1)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# Introduzca url a investigar:https://adaptive-training.com/
# #fl-main-content
# https://adaptive-training.com/
# https://adaptive-training.com/
# https://adaptive-training.com/objetivo/
# https://adaptive-training.com/biblioteca/
# https://adaptive-training.com/herrramientas-mineria-datos/
# https://adaptive-training.com/sobre-mi/
# https://adaptive-training.com/
# #
# https://adaptive-training.com/
# https://adaptive-training.com/objetivo/
# https://adaptive-training.com/biblioteca/
# https://adaptive-training.com/herrramientas-mineria-datos/
# https://adaptive-training.com/sobre-mi/
# https://adaptive-training.com/unidad-de-inteligencia-en-las-fundaciones-corporativas/
# https://adaptive-training.com/unidad-de-inteligencia-en-las-fundaciones-corporativas/
# https://adaptive-training.com/author/cdelgadom/
# https://adaptive-training.com/unidad-de-inteligencia-en-las-fundaciones-corporativas/
# https://adaptive-training.com/emociones-en-la-voz/
# ...

# %%
#Extraemos todas las url que aparecen en la página web y las guardamos en un fichero .TXT:
import requests
from bs4 import BeautifulSoup
 
url1=input ("Introduzca url a investigar:") 
print(url1)

reqs = requests.get(url1)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
with open("ficheroURL.txt", "w", encoding="utf-8") as f:
    for link in soup.find_all('a'):
        datos=link.get('href')
        print(datos)
        f.write(datos)
        f.write("\n")

print("ficheroURL.txt creado")
# Out:
# Introduzca url a investigar:https://adaptive-training.com/
# https://adaptive-training.com/
# #fl-main-content
# https://adaptive-training.com/
# https://adaptive-training.com/
# https://adaptive-training.com/objetivo/
# https://adaptive-training.com/biblioteca/
# https://adaptive-training.com/herrramientas-mineria-datos/
# https://adaptive-training.com/sobre-mi/
# https://adaptive-training.com/
# #
# https://adaptive-training.com/
# https://adaptive-training.com/objetivo/
# https://adaptive-training.com/biblioteca/
# https://adaptive-training.com/herrramientas-mineria-datos/
# https://adaptive-training.com/sobre-mi/
# https://adaptive-training.com/unidad-de-inteligencia-en-las-fundaciones-corporativas/
# https://adaptive-training.com/unidad-de-inteligencia-en-las-fundaciones-corporativas/
# https://adaptive-training.com/author/cdelgadom/
# https://adaptive-training.com/unidad-de-inteligencia-en-las-fundaciones-corporativas/
# https://adaptive-training.com/emociones-en-la-voz/
# ...

# %%
#ejemplo paa acceder a una aplicación con acceso oauth
import requests
oauth_data = {'user': 'carlosDEL', 'pass': 'xxxx'}
resp = requests.post('https://developer.twitter.com/en/portal/products/essential', data=oauth_data)

# %%
#Comentarios y otras cadenas especiales
markup = "<b><!--Hey, buddy. Want to buy a used parser?--></b>"
soup = BeautifulSoup(markup, 'html.parser')
comment = soup.b.string
type(comment)
# <class 'bs4.element.Comment'>
# Out:
# bs4.element.Comment

# %%
print(soup.b.prettify())
# <b>
# <!--Hey, buddy. Want to buy a used parser?-->
# </b>
# Out:
# <b>
#  <!--Hey, buddy. Want to buy a used parser?-->
# </b>

# %% [markdown]
# Navegando por el documento inicial “three sisters” hacia abajo:

# %%
soup.head
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.body.b
# Out:
# <b>The Dormouse's story</b>

# %%
len(soup.contents)
# Out:
# 1

# %%
soup.contents[0].name
# Out:
# 'html'

# %%
#vemos las cadenas
for string in soup.strings:
 print(repr(string))
# Out:
# "The Dormouse's story"
# '\n'
# '\n'
# "The Dormouse's story"
# '\n'
# 'Once upon a time there were three little sisters; and their names were\n'
# 'Elsie'
# ',\n'
# 'Lacie'
# ' and\n'
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '\n'
# '...'
# '\n'

# %%
#vemos las cadenas eliminando los espacios
for string in soup.stripped_strings:
 print(repr(string))
# Out:
# "The Dormouse's story"
# "The Dormouse's story"
# 'Once upon a time there were three little sisters; and their names were'
# 'Elsie'
# ','
# 'Lacie'
# 'and'
# 'Tillie'
# ';\nand they lived at the bottom of a well.'
# '...'
